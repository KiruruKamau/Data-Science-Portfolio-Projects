# %%
import pandas as pd
import os
os.chdir("/users/timothy kamau/downloads/Sales_Data")

# %% [markdown]
# Merging 12 months of sales data into a single file

# %%
files = [file for file in os.listdir(".")]

all_months_data = pd.DataFrame()

for file in files:
    df = pd.read_csv(file)
    all_months_data = pd.concat([all_months_data, df])
all_months_data.to_csv("all_data.csv", index=False)

# %% [markdown]
# Read in updated dataframe

# %%
all_data = pd.read_csv("all_data.csv")
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# Augment data with additional columns

# %% [markdown]
# Task 2: Add month column

# %%
all_data["Month"] = all_data["Order Date"].str[0:2]
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# 1             NaN                                   NaN   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04

# %% [markdown]
# Clean up the data

# %% [markdown]
# Drop NaN rows

# %%
all_data = all_data.dropna(how="all")
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04

# %% [markdown]
# Find "Or" and delete it

# %%
all_data = all_data[all_data["Order Date"].str[0:2] != "Or"]
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04

# %% [markdown]
# Add Month Column

# %%
all_data["Month"] = all_data["Order Date"].str[0:2]
all_data["Month"] = all_data["Month"].astype("int32")
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %% [markdown]
# What was the best month for sales? How much was earned that month

# %% [markdown]
# Task 3: Add a sales column

# %% [markdown]
# Convert columns to the correct type

# %%
all_data["Quantity Ordered"] = pd.to_numeric(all_data["Quantity Ordered"])
all_data['Price Each'] = pd.to_numeric(all_data["Price Each"])

# %%
all_data["Sales"] = all_data["Quantity Ordered"] * all_data["Price Each"]
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99

# %% [markdown]
# What was the best month for sales

# %%
result = all_data.groupby('Month').sum()

# %%
import matplotlib.pyplot as plt
month = range(1, 13)
plt.bar(month, result["Sales"])
plt.xticks(month)
plt.ylabel("Sales in USD ($)")
plt.xlabel("Month number")
plt.show()

# %% [markdown]
# What city had the highest number of sales

# %%
all_data['City'] = all_data['Purchase Address'].apply(lambda x: x.split(',')[1].strip())
result = all_data.groupby("City")["Sales"].sum().reset_index()

# %%
plt.bar(result["City"], result["Sales"])
plt.xticks(rotation=90)
plt.ylabel("Sales per City")
plt.xlabel("US Cities")
plt.show()

# %% [markdown]
# What time should we display adveg productrtisements to maximize the likelihood of customer's buying product?

# %%
all_data["Order Date"] = pd.to_datetime(all_data["Order Date"])

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#           City
# 0       Dallas
# 2       Boston
# 3  Los Angeles
# 4  Los Angeles
# 5  Los Angeles

# %%
all_data['Hour'] = all_data["Order Date"].dt.hour
all_data.head()
# Out:
#   Order ID Product  Quantity Ordered  Price Each          Order Date  \
# 0   176558  Minute                 2       11.95 2019-04-19 08:46:00
# 2   176559  Minute                 1       99.99 2019-04-07 22:30:00
# 3   176560  Minute                 1      600.00 2019-04-12 14:38:00
# 4   176560  Minute                 1       11.99 2019-04-12 14:38:00
# 5   176561  Minute                 1       11.99 2019-04-30 09:27:00
#
#                        Purchase Address  Month   Sales         City  Hour  \
# 0          917 1st St, Dallas, TX 75001      4   23.90       Dallas     8
# 2     682 Chestnut St, Boston, MA 02215      4   99.99       Boston    22
# 3  669 Spruce St, Los Angeles, CA 90001      4  600.00  Los Angeles    14
# 4  669 Spruce St, Los Angeles, CA 90001      4   11.99  Los Angeles    14
# 5     333 8th St, Los Angeles, CA 90001      4   11.99  Los Angeles     9
#
#    Minute
# 0      46
# 2      30
# 3      38
# 4      38
# 5      27

# %%
hours = [hour for hour, df in all_data.groupby('Hour')]
plt.plot(hours, all_data.groupby(['Hour']).count())
plt.xticks(hours)
plt.grid()

#My recommendation is around 11am or 7pm

# %% [markdown]
# What products were sold together

# %%
df = all_data[all_data["Order ID"].duplicated(keep=False)]
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df = df[['Order ID', 'Grouped']].drop_duplicates()
df.head(100)
# Out:
#     Order ID                                            Grouped
# 0     176558                        Minute,Minute,Minute,Minute
# 2     176559                        Minute,Minute,Minute,Minute
# 3     176560  Minute,Minute,Minute,Minute,Minute,Minute,Minu...
# 5     176561                        Minute,Minute,Minute,Minute
# 6     176562                        Minute,Minute,Minute,Minute
# ..       ...                                                ...
# 100   176653                        Minute,Minute,Minute,Minute
# 101   176654                        Minute,Minute,Minute,Minute
# 102   176655                        Minute,Minute,Minute,Minute
# 103   176656                        Minute,Minute,Minute,Minute
# 104   176657                        Minute,Minute,Minute,Minute
#
# [100 rows x 2 columns]

# %%
all_data.head()
# Out:
#   Order ID Product  Quantity Ordered  Price Each          Order Date  \
# 0   176558  Minute                 2       11.95 2019-04-19 08:46:00
# 2   176559  Minute                 1       99.99 2019-04-07 22:30:00
# 3   176560  Minute                 1      600.00 2019-04-12 14:38:00
# 4   176560  Minute                 1       11.99 2019-04-12 14:38:00
# 5   176561  Minute                 1       11.99 2019-04-30 09:27:00
#
#                        Purchase Address  Month   Sales         City  Hour  \
# 0          917 1st St, Dallas, TX 75001      4   23.90       Dallas     8
# 2     682 Chestnut St, Boston, MA 02215      4   99.99       Boston    22
# 3  669 Spruce St, Los Angeles, CA 90001      4  600.00  Los Angeles    14
# 4  669 Spruce St, Los Angeles, CA 90001      4   11.99  Los Angeles    14
# 5     333 8th St, Los Angeles, CA 90001      4   11.99  Los Angeles     9
#
#    Minute
# 0      46
# 2      30
# 3      38
# 4      38
# 5      27
